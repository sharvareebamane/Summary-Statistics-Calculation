# %% [markdown]
# Sharvaree Shekhar Bamane.
# Task 2:-

# %%
#import module
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

import os
print('done')
# Out:
# done

# %%
#dataset
data = pd.read_csv('/content/Task 2  TH.csv')

# %%
data.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# ...

# %%
data.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.shape
# Out:
# (418, 11)

# %%
data.info
# Out:
# <bound method DataFrame.info of      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
data.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
data.describe(include='all')
# Out:
#         PassengerId      Pclass              Name   Sex         Age  \
# count    418.000000  418.000000               418   418  332.000000
# unique          NaN         NaN               418     2         NaN
# top             NaN         NaN  Kelly, Mr. James  male         NaN
# freq            NaN         NaN                 1   266         NaN
# mean    1100.500000    2.265550               NaN   NaN   30.272590
# std      120.810458    0.841838               NaN   NaN   14.181209
# min      892.000000    1.000000               NaN   NaN    0.170000
# 25%      996.250000    1.000000               NaN   NaN   21.000000
# 50%     1100.500000    3.000000               NaN   NaN   27.000000
# 75%     1204.750000    3.000000               NaN   NaN   39.000000
# max     1309.000000    3.000000               NaN   NaN   76.000000
#
#              SibSp       Parch    Ticket        Fare            Cabin Embarked
# ...

# %%
data.describe (include=["object","bool"])
# Out:
#                     Name   Sex    Ticket            Cabin Embarked
# count                418   418       418               91      418
# unique               418     2       363               76        3
# top     Kelly, Mr. James  male  PC 17608  B57 B59 B63 B66        S
# freq                   1   266         5                3      270

# %%
mean = np.mean(data)
mean
# Out:
# PassengerId    1100.500000
# Pclass            2.265550
# Age              30.272590
# SibSp             0.447368
# Parch             0.392344
# Fare             35.627188
# dtype: float64

# %%
data.median()
# Out:
# PassengerId    1100.5000
# Pclass            3.0000
# Age              27.0000
# SibSp             0.0000
# Parch             0.0000
# Fare             14.4542
# dtype: float64

# %%
data.mode()
# Out:
#      PassengerId  Pclass                                           Name   Sex  \
# 0            892     3.0                  Abbott, Master. Eugene Joseph  male
# 1            893     NaN                    Abelseth, Miss. Karen Marie   NaN
# 2            894     NaN                  Abelseth, Mr. Olaus Jorgensen   NaN
# 3            895     NaN       Abrahamsson, Mr. Abraham August Johannes   NaN
# 4            896     NaN      Abrahim, Mrs. Joseph (Sophie Halaut Easu)   NaN
# ..           ...     ...                                            ...   ...
# 413         1305     NaN                     de Brito, Mr. Jose Joaquim   NaN
# 414         1306     NaN           de Messemaeker, Mr. Guillaume Joseph   NaN
# 415         1307     NaN  del Carlo, Mrs. Sebastiano (Argenia Genovesi)   NaN
# 416         1308     NaN            van Billiard, Master. James William   NaN
# 417         1309     NaN              van Billiard, Master. Walter John   NaN
#
# ...

# %%
data['Ticket'].mode()
# Out:
# 0    PC 17608
# Name: Ticket, dtype: object

# %%
std=np.std(data)
std
# Out:
# PassengerId    120.665861
# Pclass           0.840830
# Age             14.159836
# SibSp            0.895686
# Parch            0.980254
# Fare            55.840500
# dtype: float64

# %%
data.count()
# Out:
# PassengerId    418
# Pclass         418
# Name           418
# Sex            418
# Age            332
# SibSp          418
# Parch          418
# Ticket         418
# Fare           417
# Cabin           91
# Embarked       418
# dtype: int64

# %%
data.corr()
# Out:
#              PassengerId    Pclass       Age     SibSp     Parch      Fare
# PassengerId     1.000000 -0.026751 -0.034102  0.003818  0.043080  0.008211
# Pclass         -0.026751  1.000000 -0.492143  0.001087  0.018721 -0.577147
# Age            -0.034102 -0.492143  1.000000 -0.091587 -0.061249  0.337932
# SibSp           0.003818  0.001087 -0.091587  1.000000  0.306895  0.171539
# Parch           0.043080  0.018721 -0.061249  0.306895  1.000000  0.230046
# Fare            0.008211 -0.577147  0.337932  0.171539  0.230046  1.000000

# %%
survived_summary = data.groupby("Name")
survived_summary.mean().reset_index()
# Out:
#                                               Name  PassengerId  Pclass   Age  \
# 0                    Abbott, Master. Eugene Joseph       1284.0     3.0  13.0
# 1                      Abelseth, Miss. Karen Marie       1237.0     3.0  16.0
# 2                    Abelseth, Mr. Olaus Jorgensen        949.0     3.0  25.0
# 3         Abrahamsson, Mr. Abraham August Johannes       1143.0     3.0  20.0
# 4        Abrahim, Mrs. Joseph (Sophie Halaut Easu)        900.0     3.0  18.0
# ..                                             ...          ...     ...   ...
# 413                     de Brito, Mr. Jose Joaquim       1228.0     2.0  32.0
# 414           de Messemaeker, Mr. Guillaume Joseph       1152.0     3.0  36.5
# 415  del Carlo, Mrs. Sebastiano (Argenia Genovesi)        907.0     2.0  24.0
# 416            van Billiard, Master. James William       1236.0     3.0   NaN
# 417              van Billiard, Master. Walter John       1084.0     3.0  11.5
#
#      SibSp  Parch     Fare
# ...

# %%
survived_summary = data.groupby("Sex")
survived_summary.mean().reset_index()
# Out:
#       Sex  PassengerId    Pclass        Age     SibSp     Parch       Fare
# 0  female  1096.789474  2.144737  30.272362  0.565789  0.598684  49.747699
# 1    male  1102.620301  2.334586  30.272732  0.379699  0.274436  27.527877

# %%
survived_summary = data.groupby("Pclass")
survived_summary.mean().reset_index()
# Out:
#    Pclass  PassengerId        Age     SibSp     Parch       Fare
# 0       1  1098.224299  40.918367  0.476636  0.383178  94.280297
# 1       2  1117.935484  28.777500  0.376344  0.344086  22.202104
# 2       3  1094.178899  24.027945  0.463303  0.417431  12.459678

# %%
pd.DataFrame(abs(data.corr()['Age']).sort_values(ascending=False))
# Out:
#                   Age
# Age          1.000000
# Pclass       0.492143
# Fare         0.337932
# SibSp        0.091587
# Parch        0.061249
# PassengerId  0.034102

# %%
#the most imp variable
corr = data.corr()**2

# %%
corr.Age.sort_values(ascending = False)
# Out:
# Age            1.000000
# Pclass         0.242204
# Fare           0.114198
# SibSp          0.008388
# Parch          0.003751
# PassengerId    0.001163
# Name: Age, dtype: float64
